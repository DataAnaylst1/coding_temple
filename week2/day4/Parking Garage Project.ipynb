# %% [markdown]
# # Parking Garage Project
#
# Your assignment for today is to create a parking garage class to get more familiar with Object Oriented Programming(OOP).
#
# Your parking gargage class should have the following methods:
# - takeTicket
#    - This should decrease the amount of tickets available by 1
#    - This should decrease the amount of parkingSpaces available by 1
# - payForParking
#    - Display an input that waits for an amount from the user and store it in a variable
#    - If the payment variable is not empty then ->  display a message to the user that their ticket has been paid and they have 15mins to leave
#    - This should update the "currentTicket" dictionary key "paid" to True
# -leaveGarage
#    - If the ticket has been paid, display a message of "Thank You, have a nice day"
#    - If the ticket has not been paid, display an input prompt for payment
#       - Once paid, display message "Thank you, have a nice day!"
#    - Update parkingSpaces list to increase by 1
#    - Update tickets list to increase by 1
#
# You will need a few attributes as well:
# - tickets -> list
# - parkingSpaces -> list
# - currentTicket -> dictionary

# %%
# Your Code will go here
class ParkingGarage:
    """
    This ParkingGarage will have tickets capacity, parkingSpaces availability, and currentTicket.

    The attributes for this class are:
    - tickets_capacity: This will be a list.
    - parkingSpaces_availability: This will be a list.
    - currentTicket: This will be a dictionary.

    The methods for this class are:
    - take_ticket: this will decrease the ticket availability and the amount of parking spaces
    -pay_for_parking: user will pay for parking

    """
    def __init__(self, tickets: list, parking_spaces: list, current_ticket: dict):
        self.tickets = tickets
        self.parking_spaces = parking_spaces
        self.current_tickets = current_ticket

    def take_ticket(self):
        """This enables the user to take a ticket"""
        print("please take your ticket. You have selected a 2 hour time slot.")
        self.tickets -= 1
        self.parking_spaces -= 1

    def pay_for_parking(self):
        """This is where the user can pay for parking based on user input"""
        payment = input("Please enter payment amount on the screen.\n$20 ")
        if payment.isdigit() and payment == 20:
            print("Your ticket has been paid and your have 15 minutes left.\nHave a great day!")
            self.parking_spaces += 1
            self.tickets += 1
            self.current_tickets['Paid'] = True - 'leave_garage'
        if payment == " ":
            input("Error with input. Please enter proper amount found on the screen: $20 ")
            print("Your ticket has been paid and your have 15 minutes left.\nHave a great day")
            self.parking_spaces += 1
            self.tickets += 1
            self.current_tickets['Paid'] = True
        else:
            payment: input("The input enter could not be identified.\nPlease enter the correct amount found on the screen: $20 ")
            print("Your ticket has been paid and your have 15 minutes left.\nHave a great day!")
            self.parking_spaces += 1
            self.tickets += 1
            self.current_tickets['Paid'] = True
